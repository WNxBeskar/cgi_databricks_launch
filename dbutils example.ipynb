# %%
list_of_files = dbutils.fs.ls("/Volumes/workspace/bronze_layer/landing/transactions/")

# %%
list_of_files[1]

# %%
spark.read.format("csv").option("header", "true").option("inferSchema", "true").load("/Volumes/workspace/bronze_layer/landing/transactions/").display()

# %%
spark.sql(f"""
            SELECT * 
            FROM read_files("/Volumes/workspace/bronze_layer/landing/transactions/")
          """)

# %%
# %sql
SELECT * 
FROM read_files("/Volumes/workspace/bronze_layer/landing/transactions/")

# %%
_sqldf.describe()
